# %%
# NIRMALYA_THAKURTA_2052_DM_LAB_13
# Categorical Encoading Assignment 7-Engineering-Rare-Categories

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# to split the datasets
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None) # to display the total number columns present in the dataset

# %%
# let's load the house price dataset

data = pd.read_csv('houseprice.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
X_train,X_test,Y_train,Y_test=train_test_split(data.loc[:,data.columns!='SalePrice'],data.loc[:,data.columns=='SalePrice'],test_size=0.3)

X_train.shape, X_test.shape
# Out:
# ((1022, 80), (438, 80))

# %%
for i in train:
    if len(train[i].value_counts())<3:
        print(i)
        print(train[i].value_counts(normalize=True))
        print()
# Out:
# Street
# Pave    0.995108
# Grvl    0.004892
# Name: Street, dtype: float64
#
# Alley
# Pave    0.516129
# Grvl    0.483871
# Name: Alley, dtype: float64
#
# Utilities
# AllPub    0.999022
# NoSeWa    0.000978
# Name: Utilities, dtype: float64
#
# CentralAir
# Y    0.931507
# N    0.068493
# Name: CentralAir, dtype: float64
#
# PoolQC
# Gd    0.666667
# Ex    0.333333
# Name: PoolQC, dtype: float64

# %%
# the columns in the below list have only 4 different labels; consider cols = ['MasVnrType', 'ExterQual', 'BsmtCond']
for i in train:
    if len(train[i].value_counts())>10:
        print(i)
        print(train[i].value_counts(normalize=True))
        print()
# Out:
# Id
# 1       0.000978
# 974     0.000978
# 955     0.000978
# 956     0.000978
# 957     0.000978
#           ...
# 494     0.000978
# 496     0.000978
# 497     0.000978
# 498     0.000978
# 1460    0.000978
# Name: Id, Length: 1022, dtype: float64
#
# MSSubClass
# 20     0.368885
# 60     0.210372
# 50     0.096869
# 120    0.058708
# 160    0.046967
# 30     0.045988
# 70     0.044031
# 80     0.035225
# 90     0.032290
# 190    0.020548
# 85     0.012720
# 45     0.010763
# 75     0.009785
# 180    0.003914
# 40     0.002935
# Name: MSSubClass, dtype: float64
#
# LotFrontage
# 60.0     0.112845
# 80.0     0.067227
# 50.0     0.049220
# 70.0     0.043217
# 75.0     0.043217
#            ...
# 174.0    0.001200
# 168.0    0.001200
# 103.0    0.001200
# 114.0    0.001200
# 128.0    0.001200
# Name: LotFrontage, Length: 101, dtype: float64
#
# LotArea
# 9600     0.018591
# 7200     0.014677
# 6000     0.012720
# 10800    0.011742
# 8400     0.009785
#            ...
# 8930     0.000978
# 8935     0.000978
# 8944     0.000978
# 6897     0.000978
# 8190     0.000978
# Name: LotArea, Length: 790, dtype: float64
#
# Neighborhood
# NAmes      0.147750
# CollgCr    0.102740
# OldTown    0.071429
# Edwards    0.069472
# Sawyer     0.059687
# Somerst    0.054795
# Gilbert    0.053816
# NWAmes     0.049902
# NridgHt    0.049902
# SawyerW    0.044031
# BrkSide    0.040117
# Mitchel    0.035225
# Crawfor    0.034247
# NoRidge    0.029354
# Timber     0.029354
# ClearCr    0.023483
# IDOTRR     0.023483
# SWISU      0.017613
# StoneBr    0.015656
# MeadowV    0.011742
# Blmngtn    0.011742
# BrDale     0.009785
# NPkVill    0.006849
# Veenker    0.005871
# Blueste    0.001957
# Name: Neighborhood, dtype: float64
#
# YearBuilt
# 2005    0.044031
# 2006    0.043053
# 2003    0.032290
# 2007    0.032290
# 2004    0.032290
#           ...
# 1905    0.000978
# 1904    0.000978
# 1898    0.000978
# 1892    0.000978
# 2010    0.000978
# Name: YearBuilt, Length: 107, dtype: float64
#
# YearRemodAdd
# 1950    0.124266
# 2006    0.063601
# 2007    0.048924
# 2005    0.043053
# 2004    0.042074
#           ...
# 1955    0.003914
# 1984    0.003914
# 1986    0.002935
# 1951    0.001957
# 1952    0.001957
# Name: YearRemodAdd, Length: 61, dtype: float64
#
# Exterior1st
# VinylSd    0.356164
# HdBoard    0.149706
# Wd Sdng    0.144814
# MetalSd    0.135029
# Plywood    0.084149
# CemntBd    0.038160
# BrkFace    0.034247
# WdShing    0.020548
# Stucco     0.016634
# AsbShng    0.014677
# Stone      0.001957
# ImStucc    0.000978
# AsphShn    0.000978
# BrkComm    0.000978
# CBlock     0.000978
# Name: Exterior1st, dtype: float64
#
# Exterior2nd
# VinylSd    0.345401
# Wd Sdng    0.138943
# HdBoard    0.137965
# MetalSd    0.133072
# Plywood    0.109589
# CmentBd    0.038160
# Wd Shng    0.028376
# BrkFace    0.017613
# AsbShng    0.016634
# Stucco     0.015656
# ImStucc    0.007828
# Stone      0.003914
# Brk Cmn    0.003914
# Other      0.000978
# AsphShn    0.000978
# CBlock     0.000978
# Name: Exterior2nd, dtype: float64
#
# MasVnrArea
# 0.0      0.597837
# 16.0     0.006883
# 108.0    0.005900
# 106.0    0.005900
# 320.0    0.004916
#            ...
# 147.0    0.000983
# 388.0    0.000983
# 66.0     0.000983
# 65.0     0.000983
# 894.0    0.000983
# Name: MasVnrArea, Length: 261, dtype: float64
#
# BsmtFinSF1
# 0       0.319961
# 24      0.007828
# 16      0.006849
# 600     0.003914
# 641     0.003914
#           ...
# 490     0.000978
# 489     0.000978
# 486     0.000978
# 485     0.000978
# 1022    0.000978
# Name: BsmtFinSF1, Length: 503, dtype: float64
#
# BsmtFinSF2
# 0       0.877691
# 180     0.003914
# 374     0.002935
# 93      0.001957
# 551     0.001957
#           ...
# 208     0.000978
# 202     0.000978
# 193     0.000978
# 184     0.000978
# 1120    0.000978
# Name: BsmtFinSF2, Length: 113, dtype: float64
#
# BsmtUnfSF
# 0      0.076321
# 728    0.006849
# 600    0.006849
# 572    0.005871
# 440    0.005871
#          ...
# 485    0.000978
# 166    0.000978
# 483    0.000978
# 482    0.000978
# 359    0.000978
# Name: BsmtUnfSF, Length: 627, dtype: float64
#
# TotalBsmtSF
# 0       0.023483
# 864     0.023483
# 672     0.012720
# 816     0.011742
# 912     0.011742
#           ...
# 1468    0.000978
# 1462    0.000978
# 1459    0.000978
# 662     0.000978
# 1020    0.000978
# Name: TotalBsmtSF, Length: 573, dtype: float64
#
# 1stFlrSF
# 864     0.013699
# 912     0.010763
# 672     0.009785
# 1040    0.008806
# 894     0.008806
#           ...
# 1407    0.000978
# 1405    0.000978
# 372     0.000978
# 1394    0.000978
# 1549    0.000978
# Name: 1stFlrSF, Length: 617, dtype: float64
#
# 2ndFlrSF
# 0       0.562622
# 546     0.006849
# 504     0.006849
# 672     0.006849
# 728     0.005871
#           ...
# 1028    0.000978
# 220     0.000978
# 653     0.000978
# 1243    0.000978
# 650     0.000978
# Name: 2ndFlrSF, Length: 326, dtype: float64
#
# LowQualFinSF
# 0      0.981409
# 80     0.002935
# 390    0.000978
# 528    0.000978
# 515    0.000978
# 514    0.000978
# 513    0.000978
# 420    0.000978
# 392    0.000978
# 384    0.000978
# 53     0.000978
# 360    0.000978
# 234    0.000978
# 232    0.000978
# 205    0.000978
# 144    0.000978
# 120    0.000978
# 572    0.000978
# Name: LowQualFinSF, dtype: float64
#
# GrLivArea
# 864     0.011742
# 1200    0.007828
# 894     0.007828
# 1456    0.006849
# 912     0.006849
#           ...
# 2207    0.000978
# 2574    0.000978
# 1548    0.000978
# 1547    0.000978
# 2810    0.000978
# Name: GrLivArea, Length: 670, dtype: float64
#
# TotRmsAbvGrd
# 6     0.268102
# 7     0.228963
# 5     0.184932
# 8     0.136008
# 4     0.065558
# 9     0.051859
# 10    0.034247
# 11    0.014677
# 3     0.009785
# 12    0.003914
# 2     0.000978
# 14    0.000978
# Name: TotRmsAbvGrd, dtype: float64
#
# GarageYrBlt
# 2005.0    0.047521
# 2006.0    0.041322
# 2003.0    0.038223
# 2004.0    0.034091
# 2007.0    0.030992
#             ...
# 1908.0    0.001033
# 1915.0    0.001033
# 1927.0    0.001033
# 1906.0    0.001033
# 1900.0    0.001033
# Name: GarageYrBlt, Length: 94, dtype: float64
#
# GarageArea
# 0       0.052838
# 440     0.033268
# 576     0.030333
# 528     0.026419
# 240     0.024462
#           ...
# 551     0.000978
# 552     0.000978
# 555     0.000978
# 556     0.000978
# 1020    0.000978
# Name: GarageArea, Length: 376, dtype: float64
#
# WoodDeckSF
# 0      0.531311
# 192    0.027397
# 144    0.022505
# 100    0.021526
# 120    0.020548
#          ...
# 97     0.000978
# 95     0.000978
# 229    0.000978
# 232    0.000978
# 736    0.000978
# Name: WoodDeckSF, Length: 225, dtype: float64
#
# OpenPorchSF
# 0      0.451076
# 36     0.019569
# 40     0.015656
# 48     0.015656
# 60     0.013699
#          ...
# 156    0.000978
# 82     0.000978
# 83     0.000978
# 85     0.000978
# 547    0.000978
# Name: OpenPorchSF, Length: 173, dtype: float64
#
# EnclosedPorch
# 0      0.851272
# 112    0.009785
# 96     0.005871
# 216    0.003914
# 120    0.003914
#          ...
# 129    0.000978
# 126    0.000978
# 123    0.000978
# 115    0.000978
# 552    0.000978
# Name: EnclosedPorch, Length: 103, dtype: float64
#
# 3SsnPorch
# 0      0.983366
# 168    0.001957
# 182    0.000978
# 304    0.000978
# 290    0.000978
# 245    0.000978
# 238    0.000978
# 216    0.000978
# 196    0.000978
# 180    0.000978
# 23     0.000978
# 162    0.000978
# 153    0.000978
# 140    0.000978
# 130    0.000978
# 96     0.000978
# 508    0.000978
# Name: 3SsnPorch, dtype: float64
#
# ScreenPorch
# 0      0.915851
# 192    0.003914
# 180    0.003914
# 189    0.002935
# 90     0.002935
#          ...
# 178    0.000978
# 40     0.000978
# 63     0.000978
# 185    0.000978
# 480    0.000978
# Name: ScreenPorch, Length: 62, dtype: float64
#
# MiscVal
# 0        0.957926
# 400      0.008806
# 500      0.005871
# 450      0.003914
# 700      0.002935
# 2000     0.002935
# 1200     0.001957
# 480      0.001957
# 600      0.001957
# 1300     0.000978
# 350      0.000978
# 1400     0.000978
# 54       0.000978
# 15500    0.000978
# 2500     0.000978
# 1150     0.000978
# 560      0.000978
# 620      0.000978
# 8300     0.000978
# 800      0.000978
# 3500     0.000978
# Name: MiscVal, dtype: float64
#
# MoSold
# 6     0.177104
# 7     0.160470
# 5     0.136986
# 4     0.104697
# 8     0.073386
# 3     0.071429
# 10    0.061644
# 11    0.058708
# 9     0.042074
# 1     0.040117
# 12    0.038160
# 2     0.035225
# Name: MoSold, dtype: float64
#
# SalePrice
# 140000    0.015656
# 135000    0.012720
# 130000    0.009785
# 190000    0.008806
# 180000    0.008806
#             ...
# 130250    0.000978
# 402000    0.000978
# 111250    0.000978
# 159950    0.000978
# 185500    0.000978
# Name: SalePrice, Length: 532, dtype: float64

# %%
for i in X_train:
    if i in ['MasVnrType', 'ExterQual', 'BsmtCond']:
        print(i)
        print(X_train[i].value_counts(normalize=True))
        print()
# Out:
# MasVnrType
# None       0.591356
# BrkFace    0.312377
# Stone      0.088409
# BrkCmn     0.007859
# Name: MasVnrType, dtype: float64
#
# ExterQual
# TA    0.609589
# Gd    0.345401
# Ex    0.035225
# Fa    0.009785
# Name: ExterQual, dtype: float64
#
# BsmtCond
# TA    0.918756
# Gd    0.048144
# Fa    0.031093
# Po    0.002006
# Name: BsmtCond, dtype: float64

# %%
# let's explore examples in which variables have several categories, say more than 10

for i in X_train:
    if len(X_train[i].unique())>10:
        print(i)
        print(X_train[i].value_counts(normalize=True))
        print()
# Out:
# Id
# 1       0.000978
# 973     0.000978
# 954     0.000978
# 955     0.000978
# 959     0.000978
#           ...
# 491     0.000978
# 494     0.000978
# 495     0.000978
# 498     0.000978
# 1458    0.000978
# Name: Id, Length: 1022, dtype: float64
#
# MSSubClass
# 20     0.358121
# 60     0.203523
# 50     0.097847
# 120    0.063601
# 30     0.048924
# 80     0.045010
# 160    0.042074
# 70     0.039139
# 90     0.036204
# 190    0.019569
# 85     0.016634
# 75     0.010763
# 45     0.009785
# 180    0.006849
# 40     0.001957
# Name: MSSubClass, dtype: float64
#
# LotFrontage
# 60.0     0.103365
# 80.0     0.060096
# 70.0     0.060096
# 50.0     0.057692
# 75.0     0.044471
#            ...
# 129.0    0.001202
# 118.0    0.001202
# 114.0    0.001202
# 144.0    0.001202
# 174.0    0.001202
# Name: LotFrontage, Length: 99, dtype: float64
#
# LotArea
# 9600     0.016634
# 7200     0.013699
# 6000     0.012720
# 10800    0.009785
# 9000     0.008806
#            ...
# 12800    0.000978
# 13006    0.000978
# 17104    0.000978
# 9464     0.000978
# 16381    0.000978
# Name: LotArea, Length: 790, dtype: float64
#
# Neighborhood
# NAmes      0.142857
# CollgCr    0.107632
# OldTown    0.080235
# Edwards    0.067515
# Somerst    0.061644
# Gilbert    0.061644
# Sawyer     0.054795
# NridgHt    0.052838
# NWAmes     0.045010
# BrkSide    0.041096
# SawyerW    0.041096
# Mitchel    0.038160
# Crawfor    0.035225
# Timber     0.026419
# NoRidge    0.025440
# IDOTRR     0.022505
# StoneBr    0.016634
# ClearCr    0.016634
# SWISU      0.014677
# Blmngtn    0.013699
# BrDale     0.009785
# MeadowV    0.008806
# Veenker    0.007828
# NPkVill    0.007828
# Name: Neighborhood, dtype: float64
#
# YearBuilt
# 2006    0.045988
# 2005    0.044031
# 2007    0.038160
# 2004    0.037182
# 2003    0.035225
#           ...
# 1913    0.000978
# 1938    0.000978
# 1934    0.000978
# 1929    0.000978
# 1875    0.000978
# Name: YearBuilt, Length: 108, dtype: float64
#
# YearRemodAdd
# 1950    0.118395
# 2006    0.064579
# 2007    0.060665
# 2005    0.046967
# 2004    0.044031
#           ...
# 1986    0.003914
# 1952    0.003914
# 1983    0.002935
# 1951    0.001957
# 2010    0.001957
# Name: YearRemodAdd, Length: 61, dtype: float64
#
# Exterior1st
# VinylSd    0.362035
# HdBoard    0.159491
# MetalSd    0.143836
# Wd Sdng    0.135029
# Plywood    0.070450
# CemntBd    0.038160
# BrkFace    0.028376
# Stucco     0.022505
# WdShing    0.020548
# AsbShng    0.014677
# BrkComm    0.001957
# Stone      0.000978
# AsphShn    0.000978
# CBlock     0.000978
# Name: Exterior1st, dtype: float64
#
# Exterior2nd
# VinylSd    0.352250
# HdBoard    0.149706
# MetalSd    0.139922
# Wd Sdng    0.132094
# Plywood    0.089041
# CmentBd    0.037182
# Wd Shng    0.029354
# Stucco     0.021526
# AsbShng    0.014677
# BrkFace    0.013699
# ImStucc    0.005871
# Brk Cmn    0.005871
# Stone      0.003914
# AsphShn    0.002935
# Other      0.000978
# CBlock     0.000978
# Name: Exterior2nd, dtype: float64
#
# MasVnrArea
# 0.0      0.590373
# 72.0     0.005894
# 108.0    0.005894
# 170.0    0.004912
# 80.0     0.004912
#            ...
# 147.0    0.000982
# 66.0     0.000982
# 528.0    0.000982
# 142.0    0.000982
# 894.0    0.000982
# Name: MasVnrArea, Length: 264, dtype: float64
#
# BsmtFinSF1
# 0       0.329746
# 24      0.007828
# 16      0.007828
# 553     0.003914
# 547     0.003914
#           ...
# 1406    0.000978
# 381     0.000978
# 380     0.000978
# 379     0.000978
# 1022    0.000978
# Name: BsmtFinSF1, Length: 487, dtype: float64
#
# BsmtFinSF2
# 0      0.885519
# 712    0.001957
# 391    0.001957
# 96     0.001957
# 469    0.001957
#          ...
# 210    0.000978
# 208    0.000978
# 202    0.000978
# 193    0.000978
# 972    0.000978
# Name: BsmtFinSF2, Length: 106, dtype: float64
#
# BsmtUnfSF
# 0       0.078278
# 572     0.005871
# 440     0.005871
# 728     0.005871
# 672     0.005871
#           ...
# 1380    0.000978
# 1436    0.000978
# 715     0.000978
# 1374    0.000978
# 812     0.000978
# Name: BsmtUnfSF, Length: 621, dtype: float64
#
# TotalBsmtSF
# 0       0.024462
# 864     0.024462
# 912     0.011742
# 768     0.010763
# 672     0.009785
#           ...
# 1726    0.000978
# 1700    0.000978
# 1463    0.000978
# 1462    0.000978
# 2046    0.000978
# Name: TotalBsmtSF, Length: 572, dtype: float64
#
# 1stFlrSF
# 864     0.017613
# 912     0.011742
# 848     0.008806
# 1040    0.008806
# 894     0.006849
#           ...
# 495     0.000978
# 1105    0.000978
# 1516    0.000978
# 1512    0.000978
# 525     0.000978
# Name: 1stFlrSF, Length: 613, dtype: float64
#
# 2ndFlrSF
# 0       0.571429
# 728     0.008806
# 720     0.005871
# 672     0.005871
# 689     0.004892
#           ...
# 653     0.000978
# 1257    0.000978
# 661     0.000978
# 665     0.000978
# 650     0.000978
# Name: 2ndFlrSF, Length: 306, dtype: float64
#
# LowQualFinSF
# 0      0.986301
# 53     0.000978
# 80     0.000978
# 120    0.000978
# 156    0.000978
# 234    0.000978
# 384    0.000978
# 392    0.000978
# 420    0.000978
# 473    0.000978
# 479    0.000978
# 481    0.000978
# 513    0.000978
# 528    0.000978
# 572    0.000978
# Name: LowQualFinSF, dtype: float64
#
# GrLivArea
# 864     0.014677
# 1040    0.008806
# 848     0.007828
# 912     0.007828
# 1456    0.007828
#           ...
# 1391    0.000978
# 2414    0.000978
# 1389    0.000978
# 1387    0.000978
# 2046    0.000978
# Name: GrLivArea, Length: 670, dtype: float64
#
# TotRmsAbvGrd
# 6     0.267123
# 7     0.231898
# 5     0.194716
# 8     0.126223
# 4     0.069472
# 9     0.047945
# 10    0.031311
# 3     0.010763
# 11    0.010763
# 12    0.008806
# 2     0.000978
# Name: TotRmsAbvGrd, dtype: float64
#
# GarageYrBlt
# 2005.0    0.045502
# 2003.0    0.042399
# 2007.0    0.042399
# 2006.0    0.040331
# 2004.0    0.039297
#             ...
# 1934.0    0.001034
# 1900.0    0.001034
# 1914.0    0.001034
# 1947.0    0.001034
# 1927.0    0.001034
# Name: GarageYrBlt, Length: 93, dtype: float64
#
# GarageArea
# 0       0.053816
# 440     0.040117
# 576     0.032290
# 240     0.023483
# 528     0.021526
#           ...
# 541     0.000978
# 548     0.000978
# 551     0.000978
# 552     0.000978
# 1020    0.000978
# Name: GarageArea, Length: 376, dtype: float64
#
# WoodDeckSF
# 0      0.518591
# 192    0.027397
# 100    0.026419
# 144    0.025440
# 120    0.024462
#          ...
# 184    0.000978
# 187    0.000978
# 188    0.000978
# 190    0.000978
# 857    0.000978
# Name: WoodDeckSF, Length: 220, dtype: float64
#
# OpenPorchSF
# 0      0.467710
# 36     0.021526
# 48     0.017613
# 45     0.014677
# 40     0.013699
#          ...
# 148    0.000978
# 142    0.000978
# 141    0.000978
# 73     0.000978
# 502    0.000978
# Name: OpenPorchSF, Length: 167, dtype: float64
#
# EnclosedPorch
# 0      0.874755
# 112    0.008806
# 216    0.003914
# 96     0.003914
# 116    0.002935
#          ...
# 50     0.000978
# 169    0.000978
# 170    0.000978
# 172    0.000978
# 552    0.000978
# Name: EnclosedPorch, Length: 88, dtype: float64
#
# 3SsnPorch
# 0      0.983366
# 168    0.002935
# 216    0.001957
# 23     0.000978
# 144    0.000978
# 153    0.000978
# 182    0.000978
# 196    0.000978
# 238    0.000978
# 245    0.000978
# 290    0.000978
# 304    0.000978
# 320    0.000978
# 407    0.000978
# 508    0.000978
# Name: 3SsnPorch, dtype: float64
#
# ScreenPorch
# 0      0.917808
# 120    0.004892
# 224    0.003914
# 90     0.002935
# 192    0.002935
# 189    0.002935
# 126    0.002935
# 160    0.002935
# 144    0.002935
# 142    0.001957
# 198    0.001957
# 176    0.001957
# 170    0.001957
# 147    0.001957
# 180    0.001957
# 100    0.001957
# 143    0.000978
# 216    0.000978
# 60     0.000978
# 225    0.000978
# 233    0.000978
# 234    0.000978
# 259    0.000978
# 260    0.000978
# 263    0.000978
# 265    0.000978
# 266    0.000978
# 273    0.000978
# 276    0.000978
# 287    0.000978
# 288    0.000978
# 291    0.000978
# 374    0.000978
# 385    0.000978
# 396    0.000978
# 410    0.000978
# 222    0.000978
# 210    0.000978
# 140    0.000978
# 168    0.000978
# 145    0.000978
# 130    0.000978
# 153    0.000978
# 154    0.000978
# 155    0.000978
# 128    0.000978
# 163    0.000978
# 165    0.000978
# 122    0.000978
# 200    0.000978
# 116    0.000978
# 178    0.000978
# 40     0.000978
# 184    0.000978
# 190    0.000978
# 99     0.000978
# 197    0.000978
# 63     0.000978
# 440    0.000978
# Name: ScreenPorch, dtype: float64
#
# MiscVal
# 0        0.964775
# 400      0.008806
# 500      0.005871
# 700      0.003914
# 600      0.002935
# 2000     0.002935
# 1200     0.001957
# 450      0.001957
# 480      0.001957
# 15500    0.000978
# 1300     0.000978
# 3500     0.000978
# 2500     0.000978
# 620      0.000978
# Name: MiscVal, dtype: float64
#
# MoSold
# 6     0.168297
# 7     0.151663
# 5     0.133072
# 4     0.093933
# 8     0.084149
# 3     0.075342
# 10    0.068493
# 11    0.055773
# 12    0.047945
# 1     0.043053
# 9     0.041096
# 2     0.037182
# Name: MoSold, dtype: float64

# %%
# make plot with the above percentages
fig = plt.figure()
data.groupby('Neighborhood').size().sort_values(ascending=False).div(len(data)).plot.bar(ylabel='Percentage of Houses')
plt.axhline(y=0.05,linewidth=1, color='red')
plt.show()
data.groupby('Exterior1st').size().sort_values(ascending=False).div(len(data)).plot.bar(ylabel='Percentage of Houses')
plt.axhline(y=0.05,linewidth=1, color='red')
plt.show()
data.groupby('Exterior2nd').size().sort_values(ascending=False).div(len(data)).plot.bar(ylabel='Percentage of Houses')
plt.axhline(y=0.05,linewidth=1, color='red')
plt.show()


# add a line at 5 % to flag the threshold for rare categories

# %%
data['Neighborhood']=data['Neighborhood'].mask(data['Neighborhood'].map(data['Neighborhood'].value_counts(normalize=True)) < 0.05, 'Rare')
data['Exterior1st']=data['Exterior1st'].mask(data['Exterior1st'].map(data['Exterior1st'].value_counts(normalize=True)) < 0.05, 'Rare')
data['Exterior2nd']=data['Exterior2nd'].mask(data['Exterior2nd'].map(data['Exterior2nd'].value_counts(normalize=True)) < 0.05, 'Rare')

# make plot with the above percentages

fig = plt.figure()
data.groupby('Neighborhood').size().sort_values(ascending=False).div(len(data)).plot.bar(ylabel='Percentage of Houses')
plt.axhline(y=0.05,linewidth=1, color='red')
plt.show()
data.groupby('Exterior1st').size().sort_values(ascending=False).div(len(data)).plot.bar(ylabel='Percentage of Houses')
plt.axhline(y=0.05,linewidth=1, color='red')
plt.show()
data.groupby('Exterior2nd').size().sort_values(ascending=False).div(len(data)).plot.bar(ylabel='Percentage of Houses')
plt.axhline(y=0.05,linewidth=1, color='red')
plt.show()
# add a line at 5 % to flag the threshold for rare categories

# %% [markdown]
# # Use Feature Engine for achieving the same

# %%
from feature_engine.encoding import RareLabelEncoder

# %%
data = pd.read_csv('houseprice.csv')

# %%
# Use Rare value encoder

X_train,X_test,Y_train,Y_test=train_test_split(data.loc[:,data.columns!='SalePrice'],data.loc[:,data.columns=='SalePrice'],test_size=0.3)

X_train.shape, X_test.shape
# Out:
# ((1022, 80), (438, 80))

# %%
rle=RareLabelEncoder(tol=0.05,n_categories=0,max_n_categories=3,replace_with='Rare')
for i in X_train:
    X_train[i].fillna(X_train[i].mode()[0],inplace=True)

# %%
rle.fit_transform(X_train)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 463    464          70       RL         74.0    11988   Pave  Grvl      IR1
# 368    369          20       RL         78.0     7800   Pave  Grvl      Reg
# 810    811          20       RL         78.0    10140   Pave  Grvl      Reg
# 580    581          20       RL         60.0    14585   Pave  Grvl      IR1
# 339    340          20       RL         66.0    12400   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 820    821          60       RL         72.0     7226   Pave  Grvl      IR1
# 323    324          20       RM         49.0     5820   Pave  Grvl      Reg
# 1458  1459          20       RL         68.0     9717   Pave  Grvl      Reg
# 942    943          90       RL         42.0     7711   Pave  Grvl      IR1
# 1283  1284          90       RL         94.0     9400   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 463         Rare    AllPub    Inside      Rare         Rare       Norm
# 368          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 810          Lvl    AllPub    Inside       Gtl         Rare       Norm
# 580          Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 339          Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# ...          ...       ...       ...       ...          ...        ...
# 820          Lvl    AllPub   CulDSac       Gtl      CollgCr       Norm
# 323          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 942          Lvl    AllPub    Inside       Gtl         Rare       Norm
# 1283        Rare    AllPub    Corner       Gtl         Rare       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 463        Norm     1Fam     2Story            6            7       1934
# 368        Norm     1Fam     1Story            5            6       1954
# 810        Norm     1Fam     1Story            6            6       1974
# 580        Norm     1Fam     1Story            6            6       1960
# 339        Norm     1Fam     1Story            6            7       1958
# ...         ...      ...        ...          ...          ...        ...
# 820        Norm     1Fam     2Story            7            5       2003
# 323        Norm     1Fam     1Story            3            8       1955
# 1458       Norm     1Fam     1Story            5            6       1950
# 942        Norm     Rare     1Story            4            3       1977
# 1283       Norm     Rare     2Story            6            5       1971
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 463           1995       Hip  CompShg        Rare        Rare       None
# 368           1954     Gable  CompShg     HdBoard        Rare    BrkFace
# 810           1999       Hip  CompShg     HdBoard        Rare    BrkFace
# 580           1987     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 339           1998       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 820           2003     Gable  CompShg     VinylSd     VinylSd       None
# 323           2005     Gable  CompShg     VinylSd     VinylSd       None
# 1458          1996       Hip  CompShg        Rare     MetalSd       None
# 942           1977     Gable  CompShg        Rare     MetalSd       None
# 1283          1971      Rare  CompShg        Rare        Rare       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 463          0.0        TA        TA     CBlock       TA       TA
# 368        200.0        TA        TA      PConc       TA       TA
# 810         99.0        TA        TA     CBlock       TA       TA
# 580         85.0        TA        TA     CBlock       TA       TA
# 339        176.0        TA        TA     CBlock       TA     Rare
# ...          ...       ...       ...        ...      ...      ...
# 820          0.0        Gd        TA      PConc       Gd       TA
# 323          0.0        TA        Gd     CBlock       TA       TA
# 1458         0.0        TA        TA     CBlock       TA       TA
# 942          0.0        TA        TA      PConc       Gd       TA
# 1283         0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 463            No         Rare         326          Unf           0
# 368            No         Rare         540          Unf           0
# 810            No          ALQ         663         Rare         377
# 580            No         Rare         594         Rare         219
# 339            No         Rare         585          Unf           0
# ...           ...          ...         ...          ...         ...
# 820            No          Unf           0          Unf           0
# 323            No          ALQ         256          Unf           0
# 1458         Rare          GLQ          49         Rare        1029
# 942            Gd          GLQ        1440          Unf           0
# 1283           Av          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 463         389          715    GasA      Rare          Y      FuseA
# 368         728         1268    GasA        Gd          Y      SBrkr
# 810           0         1040    GasA      Rare          Y      SBrkr
# 580         331         1144    GasA        Ex          Y      SBrkr
# 339         630         1215    GasA        TA          Y      FuseA
# ...         ...          ...     ...       ...        ...        ...
# 820         798          798    GasA        Ex          Y      SBrkr
# 323         906         1162    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 942           0         1440    GasA        TA          Y      SBrkr
# 1283        912          912    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 463        849       811             0       1660             0             0
# 368       1268         0             0       1268             0             0
# 810       1309         0             0       1309             1             0
# 580       1429         0             0       1429             0             1
# 339       1215         0             0       1215             0             0
# ...        ...       ...           ...        ...           ...           ...
# 820        798       842             0       1640             0             0
# 323       1163         0             0       1163             1             0
# 1458      1078         0             0       1078             1             0
# 942       1440         0             0       1440             2             0
# 1283       912       912             0       1824             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 463          1         1             3             1          TA
# 368          1         0             2             1          TA
# 810          1         1             3             1          Gd
# 580          1         0             3             1          Gd
# 339          1         0             3             1          TA
# ...        ...       ...           ...           ...         ...
# 820          2         1             3             1          Gd
# 323          1         0             3             1          TA
# 1458         1         0             2             1          Gd
# 942          2         0             4             2          TA
# 1283         2         2             4             2          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 463              6        Typ           1          Gd     Detchd       1939.0
# 368              7        Typ           1          Gd     Attchd       1954.0
# 810              5        Typ           1        Rare     Attchd       1974.0
# 580              7        Typ           2          Gd     Attchd       1960.0
# 339              6        Typ           0          Gd     Attchd       1958.0
# ...            ...        ...         ...         ...        ...          ...
# 820              6        Typ           0          Gd     Attchd       2003.0
# 323              6        Typ           0          Gd     Attchd       1955.0
# 1458             5        Typ           0          Gd     Attchd       1950.0
# 942              8        Typ           0          Gd     Attchd       2005.0
# 1283             8        Typ           0          Gd     Attchd       2005.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 463           Unf           1         240         TA         TA          Y
# 368           Fin           1         244         TA         TA          Y
# 810           RFn           2         484         TA         TA          Y
# 580           Unf           2         572         TA         TA          Y
# 339           Unf           1         297         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 820           RFn           2         595         TA         TA          Y
# 323           Unf           1         220       Rare         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 942           Unf           0           0         TA         TA          N
# 1283          Unf           0           0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 463            0            0              0          0            0
# 368            0           98              0          0            0
# 810          265            0              0          0            0
# 580          216          110              0          0            0
# 339            0            0              0          0          234
# ...          ...          ...            ...        ...          ...
# 820            0           45              0          0            0
# 323          142           98              0          0            0
# 1458         366            0            112          0            0
# 942          321            0              0          0            0
# 1283         128            0              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 463          0     Gd  MnPrv        Shed        0       8    2008       WD
# 368          0     Gd  MnPrv        Shed        0       3    2010       WD
# 810        648   Rare   Rare        Shed        0       1    2006       WD
# 580          0     Gd  MnPrv        Shed        0       6    2007       WD
# 339          0     Gd  MnPrv        Shed        0       6    2009       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 820          0     Gd  MnPrv        Shed        0       6    2008       WD
# 323          0     Gd  MnPrv        Shed        0       7    2006       WD
# 1458         0     Gd  MnPrv        Shed        0       4    2010       WD
# 942          0     Gd  MnPrv        Shed        0       8    2007     Rare
# 1283         0     Gd  MnPrv        Shed        0       4    2010       WD
#
#      SaleCondition
# 463         Normal
# 368         Normal
# 810         Normal
# 580         Normal
# 339         Normal
# ...            ...
# 820         Normal
# 323         Normal
# 1458        Normal
# 942        Abnorml
# 1283        Normal
#
# [1022 rows x 80 columns]
